# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # For heatmaps
from mpl_toolkits.mplot3d import Axes3D  # For 3D plots
import math

# %% [markdown]
# ### Basics

# %%
# x=[1,2,3]
# y=[2,4,6]
# plt.plot(x,y)
# plt.title('Sample Graph')
# plt.xlabel('x Axis')
# plt.ylabel('yaxis')
# plt.show()

# plt.plot(x,y)
# plt.title('Sample Graph',fontdict={'fontname':'Comic Sans Ms'})
# plt.xlabel('X Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.ylabel('Y Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.show()


# plt.plot(x,y)
# plt.title('Sample Graph',fontdict={'fontname':'Comic Sans Ms'})
# plt.xlabel('X Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.ylabel('Y Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.xticks([1,2,3,4,25])
# plt.yticks([2,4,6,8,25])
# plt.show()

# sin=[i for i in range(0,50)]
# plt.plot(x,y,label='2x',color='red',linestyle='--')
# plt.plot(sin,[math.sin(i) for i in sin],label='sin curve' , color='blue',linewidth=0.5,marker='*',markeredgecolor='green')
# plt.title('Sample Graph',fontdict={'fontname':'Comic Sans Ms'})
# plt.xlabel('X Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.ylabel('Y Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.legend()
# plt.show()


# sin=[i for i in range(0,50)]
# plt.plot(x,y,'y*--',label='2x')
# plt.plot(sin,[math.sin(i) for i in sin],label='sin curve' , color='blue',linewidth=0.5,marker='*',markeredgecolor='green')
# plt.title('Sample Graph',fontdict={'fontname':'Comic Sans Ms'})
# plt.xlabel('X Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.ylabel('Y Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.legend()
# plt.show()

# %% [markdown]
# ## 1D Plottinging

# %% [markdown]
# ### 1.Histogram

# %%
data = np.random.randn(1000)  # Generate random data

print(data)
plt.hist(data, bins=100, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')
plt.grid(True)
plt.show()
# Out:
# [-6.39608103e-01  9.30387657e-02 -1.61527651e+00 -6.49019134e-02
#  -3.82004218e-01 -1.09652329e+00 -1.01778742e-02 -9.71108041e-01
#  -1.02638814e+00 -6.82253901e-01  4.57549645e-01 -8.25426762e-01
#   4.90662643e-01  1.78492215e+00  2.50307315e-01  2.22600824e+00
#  -2.05919285e+00 -2.23924939e-01  8.40808169e-01 -1.86820435e+00
#  -1.10716351e+00  4.17470923e-01 -1.43015889e+00 -1.23375155e+00
#  -1.62402018e+00 -2.27720887e+00  3.43644759e-01 -7.35159470e-02
#   1.39072300e+00 -1.68071045e-01  6.23805173e-01  3.64735413e-02
#  -1.93019440e+00 -1.22416325e-02  6.12471744e-01 -1.34981806e+00
#   1.26602621e+00 -5.08045532e-01  4.03887491e-01 -1.35768891e+00
#  -2.42812626e-01  1.41997715e+00 -3.98407728e-01  8.62345019e-01
#  -6.65489267e-01  9.14646685e-02  1.37178413e+00  3.47146118e-01
#   9.13475102e-01 -1.74449318e-01  6.83192739e-01  1.56215802e+00
#  -8.01905816e-01  6.91610862e-01  4.89002584e-01  1.60410734e+00
# ...

# %% [markdown]
# ### BarChart

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 20, 15, 25, 18]

plt.bar(categories, values, color='orange')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')
plt.show()

# %% [markdown]
# ## 2D Plotting

# %% [markdown]
# ### 1.Scatter Plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, color='red', label='Data Points')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Scatter Plot Example')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.Line Plot

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, color='blue', label='Sine Wave')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Plot Example')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3.Contour Plot

# %%
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

plt.contour(X, Y, Z, levels=20, cmap='viridis')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Contour Plot Example')
plt.colorbar()
plt.show()

# %% [markdown]
# ### 4.Heatmap

# %%
data = np.random.rand(10, 10)

sns.heatmap(data, cmap='coolwarm', annot=True)
plt.title('Heatmap Example')
plt.show()

# %% [markdown]
# ## 3D Plotting

# %% [markdown]
# ### 1.Scatter Plots

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

ax.scatter(x, y, z, color='green')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
plt.title('3D Scatter Plot Example')
plt.show()

# %% [markdown]
# ### 2.Surfface Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap='coolwarm')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
plt.title('3D Surface Plot Example')
plt.show()

# %% [markdown]
# ## Higher Dimensional Plots

# %% [markdown]
# ### 1. Parallel Coordinatestes Plot

# %%
from pandas.plotting import parallel_coordinates
import pandas as pd

df = pd.DataFrame({
    'Feature1': np.random.rand(10),
    'Feature2': np.random.rand(10),
    'Feature3': np.random.rand(10),
    'Class': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B']
})

parallel_coordinates(df, 'Class', colormap=plt.get_cmap("Set1"))
plt.title('Parallel Coordinates Plot Example')
plt.show()

# %% [markdown]
# ### 2.Andrew Plots

# %%
from pandas.plotting import andrews_curves

andrews_curves(df, 'Class', colormap='coolwarm')
plt.title('Andrews Plot Example')
plt.show()
