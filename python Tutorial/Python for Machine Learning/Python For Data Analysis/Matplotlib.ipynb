# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # For heatmaps
from mpl_toolkits.mplot3d import Axes3D  # For 3D plots
import math

# %% [markdown]
# ### Basics

# %%
x=[1,2,3]
y=[2,4,6]
plt.plot(x,y)
plt.title('Sample Graph')
plt.xlabel('x Axis')
plt.ylabel('yaxis')
plt.show()

plt.plot(x,y)
plt.title('Sample Graph',fontdict={'fontname':'Comic Sans Ms'})
plt.xlabel('X Axis',fontdict={'fontname':'Comic Sans Ms'})
plt.ylabel('Y Axis',fontdict={'fontname':'Comic Sans Ms'})
plt.show()


plt.plot(x,y)
plt.title('Sample Graph',fontdict={'fontname':'Comic Sans Ms'})
plt.xlabel('X Axis',fontdict={'fontname':'Comic Sans Ms'})
plt.ylabel('Y Axis',fontdict={'fontname':'Comic Sans Ms'})
plt.xticks([1,2,3,4,25])
plt.yticks([2,4,6,8,25])
plt.show()

sin=[i for i in range(0,50)]
plt.plot(x,y,label='2x',color='red',linestyle='--')
plt.plot(sin,[math.sin(i) for i in sin],label='sin curve' , color='blue',linewidth=0.5,marker='*',markeredgecolor='green')
plt.title('Sample Graph',fontdict={'fontname':'Comic Sans Ms'})
plt.xlabel('X Axis',fontdict={'fontname':'Comic Sans Ms'})
plt.ylabel('Y Axis',fontdict={'fontname':'Comic Sans Ms'})
# plt.xticks(x)
# plt.yticks(y)
plt.legend()
plt.show()

# %% [markdown]
# ## 1D Plottinging

# %% [markdown]
# ### 1.Histogram

# %%
data = np.random.randn(1000)  # Generate random data

print(data)
plt.hist(data, bins=100, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')
plt.grid(True)
plt.show()
# Out:
# [ 1.67087650e-01  1.78398837e+00  1.05817889e+00  3.29966385e-01
#   9.98286750e-01  1.52290297e+00  7.30808813e-01  1.58123066e+00
#  -1.63352130e+00 -3.64424347e-01  2.97237745e-01  4.76268222e-01
#   1.50015304e+00  1.91524030e+00 -7.96685538e-03  9.03504814e-01
#  -3.62456348e-01 -7.75776671e-01 -2.25678923e+00 -1.41227104e+00
#   2.76645421e-02 -5.25343631e-02 -1.80846992e+00  9.96403989e-01
#  -1.96897952e-01 -8.35811103e-01  4.18414558e-01  7.73221774e-01
#   4.80548297e-01  5.60773887e-01  1.91048484e+00  3.05146326e-01
#   3.64309517e-01  5.60237518e-01 -1.17820517e+00  9.45954167e-01
#   8.21289733e-01 -8.26270989e-02 -1.00778176e+00 -1.26164399e+00
#  -9.94286705e-01 -4.13060135e-02 -1.16140036e-01  7.84404453e-01
#   5.45784631e-01  1.05211821e-01  6.69058934e-01  1.44628224e-01
#   1.37981641e+00  2.09074897e+00  4.51433432e-01 -2.25197600e-01
#  -1.31994338e+00 -6.85150093e-01 -1.62924580e+00  7.96778121e-01
#  -7.75607998e-03  1.76392802e-01  8.35600099e-01  1.83067874e+00
#   4.37871082e-01  8.52197887e-01  2.31202608e-01 -1.85012929e+00
#   2.72085198e-01 -7.26100266e-01  1.70176214e+00  6.93428387e-01
#   2.94408423e-01  1.12078146e+00 -6.93771853e-01 -2.15733540e-01
#   5.06751027e-01 -1.07922673e-01  1.42896610e+00  4.36027689e-01
#  -7.34911481e-01 -7.51646185e-01 -6.58146124e-01  9.07979908e-01
#   8.38292645e-01  1.43975747e+00  6.74141363e-01  2.78470815e-01
#   6.70879490e-01 -2.20901357e+00  6.95884494e-01 -9.33229624e-01
#  -1.96132216e+00 -7.79722119e-01 -4.17420670e-01  1.56200543e-01
#   1.25743516e+00 -2.69793575e-01 -8.65201415e-01 -1.24834212e+00
#   1.30318656e+00  1.26057332e+00  1.70922883e-02 -1.70161447e-01
#   5.86604954e-01 -2.22128824e-02  3.14518841e-01  3.82733010e-01
#  -1.78307175e+00 -1.93536025e+00 -3.02757455e+00  1.03771572e+00]

# %% [markdown]
# ### BarChart

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 20, 15, 25, 18]

plt.bar(categories, values, color='orange')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')
plt.show()

# %% [markdown]
# ## 2D Plotting

# %% [markdown]
# ### 1.Scatter Plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, color='red', label='Data Points')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Scatter Plot Example')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.Line Plot

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, color='blue', label='Sine Wave')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Plot Example')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3.Contour Plot

# %%
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

plt.contour(X, Y, Z, levels=20, cmap='viridis')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Contour Plot Example')
plt.colorbar()
plt.show()

# %% [markdown]
# ### 4.Heatmap

# %%
data = np.random.rand(10, 10)

sns.heatmap(data, cmap='coolwarm', annot=True)
plt.title('Heatmap Example')
plt.show()

# %% [markdown]
# ## 3D Plotting

# %% [markdown]
# ### 1.Scatter Plots

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

ax.scatter(x, y, z, color='green')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
plt.title('3D Scatter Plot Example')
plt.show()

# %% [markdown]
# ### 2.Surfface Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap='coolwarm')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
plt.title('3D Surface Plot Example')
plt.show()

# %% [markdown]
# ## Higher Dimensional Plots

# %% [markdown]
# ### 1. Parallel Coordinatestes Plot

# %%
from pandas.plotting import parallel_coordinates
import pandas as pd

df = pd.DataFrame({
    'Feature1': np.random.rand(10),
    'Feature2': np.random.rand(10),
    'Feature3': np.random.rand(10),
    'Class': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B']
})

parallel_coordinates(df, 'Class', colormap=plt.get_cmap("Set1"))
plt.title('Parallel Coordinates Plot Example')
plt.show()

# %% [markdown]
# ### 2.Andrew Plots

# %%
from pandas.plotting import andrews_curves

andrews_curves(df, 'Class', colormap='coolwarm')
plt.title('Andrews Plot Example')
plt.show()
